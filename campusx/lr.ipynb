# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan-0307/Python_AIML/blob/main/campusx/lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("ashydv/advertising-dataset")
# Out:
# Using Colab cache for faster access to the 'advertising-dataset' dataset.
