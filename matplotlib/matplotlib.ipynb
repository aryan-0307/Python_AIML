# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [ 1,2,3 ]
y = [ 4,5,6 ]
plt.plot(x,y)# (1,4),(2,5),(3,6)  
plt.grid()
plt.show()

# %%
#Pyplot API

#univariate - numerical

data = {
    "Salary" : [25000, 30000, 37000, 28000, 39000, 48000, 55000, 52000, 35000, 26000, 27000, 31000, 33000, 29000, 40000, 36000, 34000, 45000, 47000, 50000]
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   37000
# 3   28000
# 4   39000

# %%
print(df.shape)
# Out:
# (20, 1)

# %% [markdown]
# ### Line PLot

# %%
plt.plot(df["Salary"],color="red",marker="o",linestyle = ":",linewidth = "2" )
plt.grid()
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.hist(df ,bins = 5 , color ="cyan")
plt.show()

# %% [markdown]
# ### BoxPlot

# %%
plt.boxplot(df)
plt.show()

# %%
df.loc[20]=[0]
plt.boxplot(df["Salary"])
plt.show()

# %%
df["Age"] = [22, 25, 29, 24, 30, 35, 40, 36, 28, 22, 23, 25, 26, 24, 31, 29, 27, 33, 35, 38]
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df["Age"] = [22, 25, 29, 24, 30, 35, 40, 36, 28, 22, 23, 25, 26, 24, 31, 29, 27, 33, 35, 38]
#       2 print(df)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (20) does not match length of index (21)

# %%
plt.plot(df)
plt.show()

# %%
df["dept"] = ['HR', 'IT', 'Finance', 'HR', 'Finance', 'IT', 'HR', 'Finance', 'IT', 'HR'] * 2
df.head()
# Out:
#    Salary     dept
# 0   25000       HR
# 1   30000       IT
# 2   37000  Finance
# 3   28000       HR
# 4   39000  Finance

# %%
df.info()
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  21 non-null     int64
# dtypes: int64(1)
# memory usage: 336.0 bytes
#     Salary
# 0    25000
# 1    30000
# 2    37000
# 3    28000
# 4    39000
# 5    48000
# 6    55000
# 7    52000
# 8    35000
# 9    26000
# 10   27000
# 11   31000
# 12   33000
# 13   29000
# 14   40000
# 15   36000
# 16   34000
# 17   45000
# 18   47000
# 19   50000
# 20       0

# %%
df.drop(20)
# Out:
#     Salary
# 0    25000
# 1    30000
# 2    37000
# 3    28000
# 4    39000
# 5    48000
# 6    55000
# 7    52000
# 8    35000
# 9    26000
# 10   27000
# 11   31000
# 12   33000
# 13   29000
# 14   40000
# 15   36000
# 16   34000
# 17   45000
# 18   47000
# 19   50000

# %%
df["dept"] = ['HR', 'IT', 'Finance', 'HR', 'Finance', 'IT', 'HR', 'Finance', 'IT', 'HR'] * 2 + ['HR']
print(df)
# Out:
#     Salary     dept
# 0    25000       HR
# 1    30000       IT
# 2    37000  Finance
# 3    28000       HR
# 4    39000  Finance
# 5    48000       IT
# 6    55000       HR
# 7    52000  Finance
# 8    35000       IT
# 9    26000       HR
# 10   27000       HR
# 11   31000       IT
# 12   33000  Finance
# 13   29000       HR
# 14   40000  Finance
# 15   36000       IT
# 16   34000       HR
# 17   45000  Finance
# 18   47000       IT
# 19   50000       HR
# 20       0       HR

# %%
df.drop(20, inplace=True)

# %%
print(df)
# Out:
#     Salary     dept
# 0    25000       HR
# 1    30000       IT
# 2    37000  Finance
# 3    28000       HR
# 4    39000  Finance
# 5    48000       IT
# 6    55000       HR
# 7    52000  Finance
# 8    35000       IT
# 9    26000       HR
# 10   27000       HR
# 11   31000       IT
# 12   33000  Finance
# 13   29000       HR
# 14   40000  Finance
# 15   36000       IT
# 16   34000       HR
# 17   45000  Finance
# 18   47000       IT
# 19   50000       HR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  20 non-null     int64
#  1   dept    20 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 480.0+ bytes

# %% [markdown]
# ### Pie Chart

# %%
count = df['dept'].value_counts()
print(count)
# Out:
# dept
# HR         8
# IT         6
# Finance    6
# Name: count, dtype: int64

# %%
plt.pie(count, labels = count.index ,autopct="%1.2f", explode = [0, 0.1, 0.2])
plt.axis("equal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.pie(count, labels = count.index ,autopct="%1.3f", explode = [0, 0.1, 0.2])
#       2 plt.axis("equal")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Countplot

# %%
plt.bar(count.index, count)
plt.show()

# %% [markdown]
# ### Scatter PLot

# %%
df["Age"] = [22, 25, 29, 24, 30, 35, 40, 36, 28, 22, 23, 25, 26, 24, 31, 29, 27, 33, 35, 38]
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       HR   22
# 1   30000       IT   25
# 2   37000  Finance   29
# 3   28000       HR   24
# 4   39000  Finance   30

# %%
plt.scatter(df["Age"], df["Salary"], color = "orange")
plt.show()

# %%
sort_age=df.sort_values("Age")
print(df["Age"])
# Out:
# 0     22
# 1     25
# 2     29
# 3     24
# 4     30
# 5     35
# 6     40
# 7     36
# 8     28
# 9     22
# 10    23
# 11    25
# 12    26
# 13    24
# 14    31
# 15    29
# 16    27
# 17    33
# 18    35
# 19    38
# Name: Age, dtype: int64

# %%
#Line PLot

plt.plot(sort_age["Age"], df["Salary"], color = "cyan", marker = "*", linewidth = "2")
plt.grid()
plt.show()

# %%
# Bar chart:

plt.bar(sort_age["Age"], df["Salary"], color = "green",width=0.5)
plt.show()

# %%
hr_sal=df[df["dept"] == "HR"]["Salary"]
print(hr_sal)
# Out:
# 0     25000
# 3     28000
# 6     55000
# 9     26000
# 10    27000
# 13    29000
# 16    34000
# 19    50000
# Name: Salary, dtype: int64

# %%
it_sal=df[df["dept"] == "IT"]["Salary"]
print(it_sal)
# Out:
# 1     30000
# 5     48000
# 8     35000
# 11    31000
# 15    36000
# 18    47000
# Name: Salary, dtype: int64

# %%
fin_sal=df[df["dept"] == "Finance"]["Salary"]
print(fin_sal)
# Out:
# 2     37000
# 4     39000
# 7     52000
# 12    33000
# 14    40000
# 17    45000
# Name: Salary, dtype: int64

# %%
plt.boxplot([hr_sal, it_sal, fin_sal], labels = ["Hr", "IT", "Finance"])
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8608\811707596.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([hr_sal, it_sal, fin_sal], labels = ["Hr", "IT", "Finance"])

# %%
# pie chart:

salary_by_dept = df.groupby("dept")["Salary"].sum()
salary_by_dept
# Out:
# dept
# Finance    246000
# HR         274000
# IT         227000
# Name: Salary, dtype: int64

# %%
plt.pie(salary_by_dept, labels = salary_by_dept.index, autopct = "%1.2f", shadow = True, explode = [0.1, 0, 0.1])
plt.axis("equal")
plt.show()

# %%
# bar plot

hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
fin_mean = sum(fin_sal)/len(fin_sal)

plt.bar(["Hr","It","Fin"],[hr_mean,it_mean,fin_mean],color =["red","cyan","blue"])
plt.grid()

# %%
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       HR   22
# 1   30000       IT   25
# 2   37000  Finance   29
# 3   28000       HR   24
# 4   39000  Finance   30

# %%
df["experience"] =  [1, 2, 4, 1.5, 5, 8, 12, 10, 4, 1, 1.2, 2, 3, 1.8, 5.5, 4.5, 3.2, 7, 8, 10]
print(df)
# Out:
#     Salary     dept  Age  experience
# 0    25000       HR   22         1.0
# 1    30000       IT   25         2.0
# 2    37000  Finance   29         4.0
# 3    28000       HR   24         1.5
# 4    39000  Finance   30         5.0
# 5    48000       IT   35         8.0
# 6    55000       HR   40        12.0
# 7    52000  Finance   36        10.0
# 8    35000       IT   28         4.0
# 9    26000       HR   22         1.0
# 10   27000       HR   23         1.2
# 11   31000       IT   25         2.0
# 12   33000  Finance   26         3.0
# 13   29000       HR   24         1.8
# 14   40000  Finance   31         5.5
# 15   36000       IT   29         4.5
# 16   34000       HR   27         3.2
# 17   45000  Finance   33         7.0
# 18   47000       IT   35         8.0
# 19   50000       HR   38        10.0

# %%
print(df)
# Out:
#     Salary     dept  Age  experience
# 0    25000       HR   22         1.0
# 9    26000       HR   22         1.0
# 10   27000       HR   23         1.2
# 3    28000       HR   24         1.5
# 13   29000       HR   24         1.8
# 11   31000       IT   25         2.0
# 1    30000       IT   25         2.0
# 12   33000  Finance   26         3.0
# 16   34000       HR   27         3.2
# 8    35000       IT   28         4.0
# 15   36000       IT   29         4.5
# 2    37000  Finance   29         4.0
# 4    39000  Finance   30         5.0
# 14   40000  Finance   31         5.5
# 17   45000  Finance   33         7.0
# 5    48000       IT   35         8.0
# 18   47000       IT   35         8.0
# 7    52000  Finance   36        10.0
# 19   50000       HR   38        10.0
# 6    55000       HR   40        12.0

# %%
# Bubble PLot:

plt.scatter(df["Age"], df["Salary"], s = df["experience"]*75, color = "yellow", edgecolors= "black")
plt.title("Age vs Salary vs Experience")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(df["Age"], df["Salary"], c = df["dept"].map({"HR": "yellow", "IT":"blue", "Finance": "orange"}))
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary vs Dept")
plt.legend()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8608\3433412244.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
color = {"HR": "yellow", "IT":"blue", "Finance": "orange"}

for dept, color in color.items():
    df_dept = df[df["dept"] == dept]
    plt.scatter(df_dept["Age"], df_dept["Salary"], c = color, label = dept)

plt.legend()

# %%
# object orientated API
fig, axs =plt.subplots(1,3, figsize = (10,5))

# %%
#Line Plot

axsp-f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 #Line Plot
# ----> 3 sort_age
#
# NameError: name 'sort_age' is not defined
